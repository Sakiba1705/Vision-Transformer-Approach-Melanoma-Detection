# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakiba1705/CLIP-Vision-Transformer-Approach-Melanoma-Detection/blob/main/ViT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
from tensorflow.keras.layers import Layer, Dense, Dropout, LayerNormalization, MultiHeadAttention, Add
from tensorflow.keras.layers import Input, Embedding, Concatenate
from tensorflow.keras.models import Model

class ClassToken(Layer):
    def __init__(self):
        super().__init__()

    def build(self, input_shape):
        w_init = tf.random_normal_initializer()
        self.w = tf.Variable(
            initial_value = w_init(shape=(1, 1, input_shape[-1]), dtype=tf.float32),
            trainable = True
        )

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        hidden_dim = self.w.shape[-1]

        cls = tf.broadcast_to(self.w, [batch_size, 1, hidden_dim])
        cls = tf.cast(cls, dtype=inputs.dtype)
        return cls

def mlp(x, cf):
    x = Dense(cf["mlp_dim"], activation="gelu")(x)
    x = Dropout(cf["dropout_rate"])(x)
    x = Dense(cf["hidden_dim"])(x)
    x = Dropout(cf["dropout_rate"])(x)
    return x

def transformer_encoder(x, cf):
    skip_1 = x
    x = LayerNormalization()(x)
    x = MultiHeadAttention(
        num_heads=cf["num_heads"], key_dim=cf["hidden_dim"]
    )(x, x)
    x = Add()([x, skip_1])

    skip_2 = x
    x = LayerNormalization()(x)
    x = mlp(x, cf)
    x = Add()([x, skip_2])

    return x

def ViT(cf):
    """ Inputs """
    input_shape = (cf["num_patches"], cf["patch_size"]*cf["patch_size"]*cf["num_channels"])
    inputs = Input(input_shape) ## (None, 256, 3072)

    """ Patch + Position Embeddings """
    patch_embed = Dense(cf["hidden_dim"])(inputs)

    positions = tf.range(start=0, limit=cf["num_patches"], delta=1) ## (256,)
    pos_embed = Embedding(input_dim=cf["num_patches"], output_dim=cf["hidden_dim"])(positions) ## (256, 768)
    embed = patch_embed + pos_embed ## (None, 256, 768)

    """ Adding Class Token """
    token = ClassToken()(embed)
    x = Concatenate(axis=1)([token, embed]) ## (None, 257, 768)

    """ Transformer Encoder """
    for _ in range(cf["num_layers"]):
        x = transformer_encoder(x, cf)

    """ Classification Head """
    x = LayerNormalization()(x) ## (None, 257, 768)
    x = x[:, 0, :] ## (None, 768)
    x = Dropout(0.1)(x)
    x = Dense(10, activation="softmax")(x)

    model = Model(inputs, x)
    return model


if __name__ == "__main__":
    config = {}
    config["num_layers"] = 12
    config["hidden_dim"] = 768
    config["mlp_dim"] = 3072
    config["num_heads"] = 12
    config["dropout_rate"] = 0.1
    config["num_patches"] = 256
    config["patch_size"] = 32
    config["num_channels"] = 3

    model = ViT(config)
    model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 3072)]  0           []
#
#  dense_26 (Dense)               (None, 256, 768)     2360064     ['input_2[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 256, 768)    0           ['dense_26[0][0]']
#  mbda)
#
#  class_token_1 (ClassToken)     (None, 1, 768)       768         ['tf.__operators__.add_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 257, 768)     0           ['class_token_1[0][0]',
#                                                                   'tf.__operators__.add_1[0][0]']
#
#  layer_normalization_25 (LayerN  (None, 257, 768)    1536        ['concatenate_1[0][0]']
#  ormalization)
#
#  multi_head_attention_12 (Multi  (None, 257, 768)    28339968    ['layer_normalization_25[0][0]',
#  HeadAttention)                                                   'layer_normalization_25[0][0]']
#
#  add_24 (Add)                   (None, 257, 768)     0           ['multi_head_attention_12[0][0]',
#                                                                   'concatenate_1[0][0]']
#
#  layer_normalization_26 (LayerN  (None, 257, 768)    1536        ['add_24[0][0]']
#  ormalization)
#
#  dense_27 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_26[0][0]']
#
#  dropout_25 (Dropout)           (None, 257, 3072)    0           ['dense_27[0][0]']
#
#  dense_28 (Dense)               (None, 257, 768)     2360064     ['dropout_25[0][0]']
#
#  dropout_26 (Dropout)           (None, 257, 768)     0           ['dense_28[0][0]']
#
#  add_25 (Add)                   (None, 257, 768)     0           ['dropout_26[0][0]',
#                                                                   'add_24[0][0]']
#
#  layer_normalization_27 (LayerN  (None, 257, 768)    1536        ['add_25[0][0]']
#  ormalization)
#
#  multi_head_attention_13 (Multi  (None, 257, 768)    28339968    ['layer_normalization_27[0][0]',
#  HeadAttention)                                                   'layer_normalization_27[0][0]']
#
#  add_26 (Add)                   (None, 257, 768)     0           ['multi_head_attention_13[0][0]',
#                                                                   'add_25[0][0]']
#
#  layer_normalization_28 (LayerN  (None, 257, 768)    1536        ['add_26[0][0]']
#  ormalization)
#
#  dense_29 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_28[0][0]']
#
#  dropout_27 (Dropout)           (None, 257, 3072)    0           ['dense_29[0][0]']
#
#  dense_30 (Dense)               (None, 257, 768)     2360064     ['dropout_27[0][0]']
#
#  dropout_28 (Dropout)           (None, 257, 768)     0           ['dense_30[0][0]']
#
#  add_27 (Add)                   (None, 257, 768)     0           ['dropout_28[0][0]',
#                                                                   'add_26[0][0]']
#
#  layer_normalization_29 (LayerN  (None, 257, 768)    1536        ['add_27[0][0]']
#  ormalization)
#
#  multi_head_attention_14 (Multi  (None, 257, 768)    28339968    ['layer_normalization_29[0][0]',
#  HeadAttention)                                                   'layer_normalization_29[0][0]']
#
#  add_28 (Add)                   (None, 257, 768)     0           ['multi_head_attention_14[0][0]',
#                                                                   'add_27[0][0]']
#
#  layer_normalization_30 (LayerN  (None, 257, 768)    1536        ['add_28[0][0]']
#  ormalization)
#
#  dense_31 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_30[0][0]']
#
#  dropout_29 (Dropout)           (None, 257, 3072)    0           ['dense_31[0][0]']
#
#  dense_32 (Dense)               (None, 257, 768)     2360064     ['dropout_29[0][0]']
#
#  dropout_30 (Dropout)           (None, 257, 768)     0           ['dense_32[0][0]']
#
#  add_29 (Add)                   (None, 257, 768)     0           ['dropout_30[0][0]',
#                                                                   'add_28[0][0]']
#
#  layer_normalization_31 (LayerN  (None, 257, 768)    1536        ['add_29[0][0]']
#  ormalization)
#
#  multi_head_attention_15 (Multi  (None, 257, 768)    28339968    ['layer_normalization_31[0][0]',
#  HeadAttention)                                                   'layer_normalization_31[0][0]']
#
#  add_30 (Add)                   (None, 257, 768)     0           ['multi_head_attention_15[0][0]',
#                                                                   'add_29[0][0]']
#
#  layer_normalization_32 (LayerN  (None, 257, 768)    1536        ['add_30[0][0]']
#  ormalization)
#
#  dense_33 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_32[0][0]']
#
#  dropout_31 (Dropout)           (None, 257, 3072)    0           ['dense_33[0][0]']
#
#  dense_34 (Dense)               (None, 257, 768)     2360064     ['dropout_31[0][0]']
#
#  dropout_32 (Dropout)           (None, 257, 768)     0           ['dense_34[0][0]']
#
#  add_31 (Add)                   (None, 257, 768)     0           ['dropout_32[0][0]',
#                                                                   'add_30[0][0]']
#
#  layer_normalization_33 (LayerN  (None, 257, 768)    1536        ['add_31[0][0]']
#  ormalization)
#
#  multi_head_attention_16 (Multi  (None, 257, 768)    28339968    ['layer_normalization_33[0][0]',
#  HeadAttention)                                                   'layer_normalization_33[0][0]']
#
#  add_32 (Add)                   (None, 257, 768)     0           ['multi_head_attention_16[0][0]',
#                                                                   'add_31[0][0]']
#
#  layer_normalization_34 (LayerN  (None, 257, 768)    1536        ['add_32[0][0]']
#  ormalization)
#
#  dense_35 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_34[0][0]']
#
#  dropout_33 (Dropout)           (None, 257, 3072)    0           ['dense_35[0][0]']
#
#  dense_36 (Dense)               (None, 257, 768)     2360064     ['dropout_33[0][0]']
#
#  dropout_34 (Dropout)           (None, 257, 768)     0           ['dense_36[0][0]']
#
#  add_33 (Add)                   (None, 257, 768)     0           ['dropout_34[0][0]',
#                                                                   'add_32[0][0]']
#
#  layer_normalization_35 (LayerN  (None, 257, 768)    1536        ['add_33[0][0]']
#  ormalization)
#
#  multi_head_attention_17 (Multi  (None, 257, 768)    28339968    ['layer_normalization_35[0][0]',
#  HeadAttention)                                                   'layer_normalization_35[0][0]']
#
#  add_34 (Add)                   (None, 257, 768)     0           ['multi_head_attention_17[0][0]',
#                                                                   'add_33[0][0]']
#
#  layer_normalization_36 (LayerN  (None, 257, 768)    1536        ['add_34[0][0]']
#  ormalization)
#
#  dense_37 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_36[0][0]']
#
#  dropout_35 (Dropout)           (None, 257, 3072)    0           ['dense_37[0][0]']
#
#  dense_38 (Dense)               (None, 257, 768)     2360064     ['dropout_35[0][0]']
#
#  dropout_36 (Dropout)           (None, 257, 768)     0           ['dense_38[0][0]']
#
#  add_35 (Add)                   (None, 257, 768)     0           ['dropout_36[0][0]',
#                                                                   'add_34[0][0]']
#
#  layer_normalization_37 (LayerN  (None, 257, 768)    1536        ['add_35[0][0]']
#  ormalization)
#
#  multi_head_attention_18 (Multi  (None, 257, 768)    28339968    ['layer_normalization_37[0][0]',
#  HeadAttention)                                                   'layer_normalization_37[0][0]']
#
#  add_36 (Add)                   (None, 257, 768)     0           ['multi_head_attention_18[0][0]',
#                                                                   'add_35[0][0]']
#
#  layer_normalization_38 (LayerN  (None, 257, 768)    1536        ['add_36[0][0]']
#  ormalization)
#
#  dense_39 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_38[0][0]']
#
#  dropout_37 (Dropout)           (None, 257, 3072)    0           ['dense_39[0][0]']
#
#  dense_40 (Dense)               (None, 257, 768)     2360064     ['dropout_37[0][0]']
#
#  dropout_38 (Dropout)           (None, 257, 768)     0           ['dense_40[0][0]']
#
#  add_37 (Add)                   (None, 257, 768)     0           ['dropout_38[0][0]',
#                                                                   'add_36[0][0]']
#
#  layer_normalization_39 (LayerN  (None, 257, 768)    1536        ['add_37[0][0]']
#  ormalization)
#
#  multi_head_attention_19 (Multi  (None, 257, 768)    28339968    ['layer_normalization_39[0][0]',
#  HeadAttention)                                                   'layer_normalization_39[0][0]']
#
#  add_38 (Add)                   (None, 257, 768)     0           ['multi_head_attention_19[0][0]',
#                                                                   'add_37[0][0]']
#
#  layer_normalization_40 (LayerN  (None, 257, 768)    1536        ['add_38[0][0]']
#  ormalization)
#
#  dense_41 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_40[0][0]']
#
#  dropout_39 (Dropout)           (None, 257, 3072)    0           ['dense_41[0][0]']
#
#  dense_42 (Dense)               (None, 257, 768)     2360064     ['dropout_39[0][0]']
#
#  dropout_40 (Dropout)           (None, 257, 768)     0           ['dense_42[0][0]']
#
#  add_39 (Add)                   (None, 257, 768)     0           ['dropout_40[0][0]',
#                                                                   'add_38[0][0]']
#
#  layer_normalization_41 (LayerN  (None, 257, 768)    1536        ['add_39[0][0]']
#  ormalization)
#
#  multi_head_attention_20 (Multi  (None, 257, 768)    28339968    ['layer_normalization_41[0][0]',
#  HeadAttention)                                                   'layer_normalization_41[0][0]']
#
#  add_40 (Add)                   (None, 257, 768)     0           ['multi_head_attention_20[0][0]',
#                                                                   'add_39[0][0]']
#
#  layer_normalization_42 (LayerN  (None, 257, 768)    1536        ['add_40[0][0]']
#  ormalization)
#
#  dense_43 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_42[0][0]']
#
#  dropout_41 (Dropout)           (None, 257, 3072)    0           ['dense_43[0][0]']
#
#  dense_44 (Dense)               (None, 257, 768)     2360064     ['dropout_41[0][0]']
#
#  dropout_42 (Dropout)           (None, 257, 768)     0           ['dense_44[0][0]']
#
#  add_41 (Add)                   (None, 257, 768)     0           ['dropout_42[0][0]',
#                                                                   'add_40[0][0]']
#
#  layer_normalization_43 (LayerN  (None, 257, 768)    1536        ['add_41[0][0]']
#  ormalization)
#
#  multi_head_attention_21 (Multi  (None, 257, 768)    28339968    ['layer_normalization_43[0][0]',
#  HeadAttention)                                                   'layer_normalization_43[0][0]']
#
#  add_42 (Add)                   (None, 257, 768)     0           ['multi_head_attention_21[0][0]',
#                                                                   'add_41[0][0]']
#
#  layer_normalization_44 (LayerN  (None, 257, 768)    1536        ['add_42[0][0]']
#  ormalization)
#
#  dense_45 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_44[0][0]']
#
#  dropout_43 (Dropout)           (None, 257, 3072)    0           ['dense_45[0][0]']
#
#  dense_46 (Dense)               (None, 257, 768)     2360064     ['dropout_43[0][0]']
#
#  dropout_44 (Dropout)           (None, 257, 768)     0           ['dense_46[0][0]']
#
#  add_43 (Add)                   (None, 257, 768)     0           ['dropout_44[0][0]',
#                                                                   'add_42[0][0]']
#
#  layer_normalization_45 (LayerN  (None, 257, 768)    1536        ['add_43[0][0]']
#  ormalization)
#
#  multi_head_attention_22 (Multi  (None, 257, 768)    28339968    ['layer_normalization_45[0][0]',
#  HeadAttention)                                                   'layer_normalization_45[0][0]']
#
#  add_44 (Add)                   (None, 257, 768)     0           ['multi_head_attention_22[0][0]',
#                                                                   'add_43[0][0]']
#
#  layer_normalization_46 (LayerN  (None, 257, 768)    1536        ['add_44[0][0]']
#  ormalization)
#
#  dense_47 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_46[0][0]']
#
#  dropout_45 (Dropout)           (None, 257, 3072)    0           ['dense_47[0][0]']
#
#  dense_48 (Dense)               (None, 257, 768)     2360064     ['dropout_45[0][0]']
#
#  dropout_46 (Dropout)           (None, 257, 768)     0           ['dense_48[0][0]']
#
#  add_45 (Add)                   (None, 257, 768)     0           ['dropout_46[0][0]',
#                                                                   'add_44[0][0]']
#
#  layer_normalization_47 (LayerN  (None, 257, 768)    1536        ['add_45[0][0]']
#  ormalization)
#
#  multi_head_attention_23 (Multi  (None, 257, 768)    28339968    ['layer_normalization_47[0][0]',
#  HeadAttention)                                                   'layer_normalization_47[0][0]']
#
#  add_46 (Add)                   (None, 257, 768)     0           ['multi_head_attention_23[0][0]',
#                                                                   'add_45[0][0]']
#
#  layer_normalization_48 (LayerN  (None, 257, 768)    1536        ['add_46[0][0]']
#  ormalization)
#
#  dense_49 (Dense)               (None, 257, 3072)    2362368     ['layer_normalization_48[0][0]']
#
#  dropout_47 (Dropout)           (None, 257, 3072)    0           ['dense_49[0][0]']
#
#  dense_50 (Dense)               (None, 257, 768)     2360064     ['dropout_47[0][0]']
#
#  dropout_48 (Dropout)           (None, 257, 768)     0           ['dense_50[0][0]']
#
#  add_47 (Add)                   (None, 257, 768)     0           ['dropout_48[0][0]',
#                                                                   'add_46[0][0]']
#
#  layer_normalization_49 (LayerN  (None, 257, 768)    1536        ['add_47[0][0]']
#  ormalization)
#
#  tf.__operators__.getitem_1 (Sl  (None, 768)         0           ['layer_normalization_49[0][0]']
#  icingOpLambda)
#
#  dropout_49 (Dropout)           (None, 768)          0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  dense_51 (Dense)               (None, 10)           7690        ['dropout_49[0][0]']
#
# ==================================================================================================
# Total params: 399,155,722
# Trainable params: 399,155,722
# Non-trainable params: 0
# __________________________________________________________________________________________________
